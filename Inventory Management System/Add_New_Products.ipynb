# %%
import json
print("_________________________________________Inventory Management System__________________________________________")
f1 = open("record.json",'r')
read = f1.read()
f1.close()
data = json.loads(read)
choice='Y'
while(choice == 'Y' or choice == 'y' ):
    print("\n---------------------------------------------")
    print("\nEnter :- \n\n> '1' to display available Products\n> '2' to display all Products Id and Name\n> '3' for adding Product\n> '4' to delete Product\n> '5' to find Product details by Product ID\n> '6' to check quantity of a product\n> '7' to update quantity of a product")
    print("\n---------------------------------------------")
    inp=int(input())
    if inp == 1:
        print(json.dumps(data, indent=1))
    elif inp == 2:
        for i in data:
            print(i," : ",data[i]['name'])
    elif inp == 3:
        p_id = str(input("Enter product id: "))
        name = str(input("Enter Product name: "))
        pr = int(input("Enter Product price: "))
        qn = int(input("Enter quantity: "))
        data[p_id] = {'name': name, 'pr': pr, 'qn': qn}
    elif inp == 4:
        del data[str(input("Enter Product ID: "))]
        print("----- Product Deleted Successfull! -----")
    elif inp == 5:
        print(data[(input("Enter Product ID: "))])
    elif inp == 6:
        p_id = str(input("Enter product id: "))
        print(data[p_id]['qn'])
    elif inp == 7:
        p_id = str(input("Enter product id: "))
        qn = int(input("Enter quantity to add: "))
        data[p_id]['qn'] = str(int(data[p_id]['qn'])+qn)
        print("----- Updation Successfull! -----")
    choice = str(input("Do you wants to perform other operations? type: 'Y' for Yes\n"))
data = json.dumps(data)
f1 = open("record.json",'w')
f1.write(data)
f1.close()
# Out:
# _________________________________________Inventory Management System__________________________________________
#
# ---------------------------------------------
#
# Enter :-
#
# > '1' to display available Products
# > '2' to display all Products Id and Name
# > '3' for adding Product
# > '4' to delete Product
# > '5' to find Product details by Product ID
# > '6' to check quantity of a product
# > '7' to update quantity of a product
#
# ---------------------------------------------
# 1
# {
#  "1001": {
#   "name": "Choco Cake",
#   "qn": 34,
#   "pr": 100
#  },
#  "1002": {
#   "name": "Milk Cake",
#   "pr": 800,
#   "qn": 100
#  },
#  "1003": {
#   "name": "Drink",
#   "pr": 85,
#   "qn": 98
#  },
#  "1004": {
#   "name": "Candy",
#   "pr": 5,
#   "qn": 999
#  },
#  "1005": {
#   "name": "Pen",
#   "pr": 20,
#   "qn": "112"
#  },
#  "1006": {
#   "name": "Phone",
#   "pr": 50000,
#   "qn": 10
#  },
#  "1007": {
#   "name": "Mic",
#   "pr": 1500,
#   "qn": 0
#  },
#  "1008": {
#   "name": "Case",
#   "pr": 599,
#   "qn": 0
#  },
#  "1009": {
#   "name": "Keyboard",
#   "pr": 1999,
#   "qn": 10
#  },
#  "1010": {
#   "name": "Hard_Disk",
#   "pr": 3999,
#   "qn": 12
#  },
#  "1011": {
#   "name": "pencil",
#   "pr": 5,
#   "qn": 133
#  },
#  "1012": {
#   "name": "book",
#   "pr": 239,
#   "qn": 298
#  },
#  "1013": {
#   "name": "basket",
#   "pr": 129,
#   "qn": 29
#  },
#  "1014": {
#   "name": "Eraser",
#   "pr": 2,
#   "qn": 120
#  },
#  "1015": {
#   "name": "Sheet",
#   "pr": 2,
#   "qn": 500
#  },
#  "1016": {
#   "name": "Flag",
#   "pr": 5,
#   "qn": 20
#  },
#  "1017": {
#   "name": "Glue",
#   "pr": 10,
#   "qn": 30
#  },
#  "1018": {
#   "name": "Fevicol",
#   "pr": 15,
#   "qn": 30
#  },
#  "1019": {
#   "name": "Graph",
#   "pr": 10,
#   "qn": 100
#  },
#  "1020": {
#   "name": "Map",
#   "pr": 2,
#   "qn": 129
#  },
#  "1021": {
#   "name": "Spark ",
#   "pr": 5,
#   "qn": 100
#  },
#  "1022": {
#   "name": "Scale",
#   "pr": 5,
#   "qn": 150
#  },
#  "1023": {
#   "name": "Gloves",
#   "pr": 99,
#   "qn": 20
#  },
#  "1024": {
#   "name": "Mask",
#   "pr": 49,
#   "qn": 399
#  },
#  "1025": {
#   "name": "Cap",
#   "pr": 239,
#   "qn": 12
#  },
#  "1026": {
#   "name": "Mat",
#   "pr": 99,
#   "qn": 2
#  }
# }
# Do you wants to perform other operations? type: 'Y' for Yes
# y
#
# ---------------------------------------------
#
# Enter :-
#
# > '1' to display available Products
# > '2' to display all Products Id and Name
# > '3' for adding Product
# > '4' to delete Product
# > '5' to find Product details by Product ID
# > '6' to check quantity of a product
# > '7' to update quantity of a product
#
# ---------------------------------------------
# 3
# Enter product id: 1027
# Enter Product name: Blanket
# Enter Product price: 999
# Enter quantity: 1
# Do you wants to perform other operations? type: 'Y' for Yes
# y
#
# ---------------------------------------------
#
# Enter :-
#
# > '1' to display available Products
# > '2' to display all Products Id and Name
# > '3' for adding Product
# > '4' to delete Product
# > '5' to find Product details by Product ID
# > '6' to check quantity of a product
# > '7' to update quantity of a product
#
# ---------------------------------------------
# 3
# Enter product id: 1028
# Enter Product name: Chain
# Enter Product price: 30
# Enter quantity: 0
# Do you wants to perform other operations? type: 'Y' for Yes
# y
#
# ---------------------------------------------
#
# Enter :-
#
# > '1' to display available Products
# > '2' to display all Products Id and Name
# > '3' for adding Product
# > '4' to delete Product
# > '5' to find Product details by Product ID
# > '6' to check quantity of a product
# > '7' to update quantity of a product
#
# ---------------------------------------------
# 3
# Enter product id: 1029
# Enter Product name: Towel
# Enter Product price: 149
# Enter quantity: 16
# Do you wants to perform other operations? type: 'Y' for Yes
# y
#
# ---------------------------------------------
#
# Enter :-
#
# > '1' to display available Products
# > '2' to display all Products Id and Name
# > '3' for adding Product
# > '4' to delete Product
# > '5' to find Product details by Product ID
# > '6' to check quantity of a product
# > '7' to update quantity of a product
#
# ---------------------------------------------
# 3
# Enter product id: 1030
# Enter Product name: Face Wash
# Enter Product price: 222
# Enter quantity: 4
# Do you wants to perform other operations? type: 'Y' for Yes
# n
